# %%
# import modules here
from prep_data import *
from visualizations import *
from sklearn.dummy import DummyClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.svm import SVC, LinearSVC
from sklearn.externals import joblib
from sklearn.linear_model import LogisticRegression

# %%
# data files
EXPERIMENT_1 = 'data/experiment1_data.csv'
EXPERIMENT_2 = 'data/experiment2_data.csv'

# %% [markdown]
# # Binary Models

# %% [markdown]
# ## Experiment 1

# %%
# prepare the data
mode = 3 
x_train, x_test, y_train, y_test = binary_prep(EXPERIMENT_1, mode, seed=None)
class_names = ['1', '0'] # 1 means an app was opened, 0 means nothing happened

# %% [markdown]
# ### Dummy Classifier
#
# Let's see how accurate we are when we use a classifier that learns nothing...

# %%
dummy = DummyClassifier()
dummy.fit(x_train, y_train)
# Make predictions
y_pred = dummy.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.74      0.65        19
#           1       0.69      0.52      0.59        21
#
# avg / total       0.64      0.62      0.62        40

# %% [markdown]
# It looks like the results are pretty bad...

# %% [markdown]
# ### Support Vector Machine

# %%
# still need to do cross validation and grid search
svc = LinearSVC()
svc.fit(x_train, y_train)
joblib.dump(svc, 'saved_models/e1_svm.pkl')
# Out:
# ['saved_models/e1_svm.pkl']

# %%
# Make predictions
y_pred = svc.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.79      0.73        19
#           1       0.78      0.67      0.72        21
#
# avg / total       0.73      0.72      0.72        40

# %% [markdown]
# ### Logistic Regression

# %%
# still need to do cross validation and grid search
lr = LogisticRegression()
lr.fit(x_train, y_train)
joblib.dump(lr, 'saved_models/e1_lr.pkl')
# Out:
# ['saved_models/e1_lr.pkl']

# %%
# Make predictions
y_pred = lr.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.95      0.84        19
#           1       0.94      0.71      0.81        21
#
# avg / total       0.85      0.82      0.82        40

# %% [markdown]
# ## Experiment 2

# %%
# prepare the data
mode = 3 
x_train, x_test, y_train, y_test = binary_prep(EXPERIMENT_2, mode, seed=None)
class_names = ['1', '0'] # 1 means an app was opened, 0 means nothing happened

# %% [markdown]
# ### Dummy Classifier

# %%
dummy = DummyClassifier()
dummy.fit(x_train, y_train)
# Make predictions
y_pred = dummy.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.52      0.57      0.54        79
#           1       0.48      0.42      0.45        73
#
# avg / total       0.50      0.50      0.50       152

# %%
# still need to do cross validation and grid search
svc = LinearSVC()
svc.fit(x_train, y_train)
joblib.dump(svc, 'saved_models/e2_svm.pkl')
# Out:
# ['saved_models/e2_svm.pkl']

# %%
# Make predictions
y_pred = svc.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.71      0.73      0.72        79
#           1       0.70      0.67      0.69        73
#
# avg / total       0.70      0.70      0.70       152

# %%
# still need to do cross validation and grid search
lr = LogisticRegression()
lr.fit(x_train, y_train)
joblib.dump(lr, 'saved_models/e2_lr.pkl')
# Out:
# ['saved_models/e2_lr.pkl']

# %%
# Make predictions
y_pred = lr.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plt.rcParams.update({'font.size':10})
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.89      0.80        79
#           1       0.84      0.64      0.73        73
#
# avg / total       0.78      0.77      0.77       152
